# %%
import csv

# will use this to pause briefly between requests, as a courtesy
from time import sleep

# pattern expansion -- will use this to get a handle to the HTML files
# we download later
from glob import glob

import requests
from bs4 import BeautifulSoup

# %%
# variable for the base URL, without query parameters
base_url = 'https://www.journalismjobs.com/job-listings'

# set up some initial query parameters -- start on page 1,
# show 100 results for each page
parameters = {
    'page': 1,
    'count': 100
}

# %%
# first task: figure out how many pages to iterate through
# by grabbing the last number in the pagination buttons at the bottom
req = requests.get(
    base_url,
    params=parameters
)

req.raise_for_status()

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="JournalismJobs.com has journalism job and media job listings for online media, newspapers, tv, radio, magazines, nonprofits, and academia." name="description">
# <meta content="journalism jobs, media jobs, reporter jobs, writing jobs, coy editing jobs, news producer jobs, online producer jobs" name="keywords">
# <link href="/assets/journalismjobs.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/assets/journalismjobs.com/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- Bootstrap CSS -->
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
# <link href="/css/fontawesome.min.css" rel="stylesheet">
# <link href="/css/brands.min.css" rel="stylesheet">
# <link href="https://cdn.jsdelivr.net/npm/bootstrap-select@1.13.9/dist/css/bootstrap-select.min.css" rel="stylesheet"/>
# <link href="/css/style.css?t=1701127706" rel="stylesheet">
# <link href="/assets/journalismjobs.com/css/layout.css?t=1692914750" rel="stylesheet">
# <title>                            JournalismJobs.com -- The Job Board for Media Professionals
#                     </title>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FYCCX3E9PN"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'G-FYCCX3E9PN');
#     </script>
# </link></link></link></link></meta></meta></head>
# <body class="app_frontend_joblistings">
# <div id="main">
# <div id="top-banner">
# </div>
# <div class="nav-bar-top">
# <div class="container-fluid container-fluid-xl">
# <header>
# <div class="logo">
# <a class="normal" href="/"><img alt="JournalismJobs.com" src="/assets/journalismjobs.com/images/logo.svg"/></a>
# <a class="dark" href="/"><img alt="JournalismJobs.com" src="/assets/journalismjobs.com/images/white-logo.svg"/></a>
# </div>
# <nav class="desktop">
# <ul>
# <li class="spacer"></li>
# <li class="search-jobs">
# <a class="active" href="#">Search Jobs</a>
# <ul class="submenu">
# <li>
# <a class="item" href="/job-listings">View All Listings</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Newspapers">Newspapers / Wire Services</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Online_Media">Digital Media / Startups</a>
# </li>
# <li>
# <a class="item" href="/job-listings/TV">Television / Radio</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Magazines">Magazines / Publishing</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Trade_Publications_Newsletters">Trade Publications / Newsletters</a>
# </li>
# <li>
# <a class="item" href="/job-listings/PR_Media_Relations_Communications">PR / Media Relations / Communications</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Nonprofit_Academia_Government">Nonprofit / Academia / Government</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Finance">Financial / Technology / Other</a>
# </li>
# <li>
# <a class="item" href="/job-listings/Diversity">Diversity Jobs</a>
# </li>
# </ul> </li>
# <li class="post-resume">
# <a class="" href="/login_post_resume">Create Profile</a>
# </li>
# <li>
# <a data-target="#jobAlertsModal" data-toggle="modal" href="#">Job Alerts</a>
# </li>
# <li class="spacer"></li>
# <li class="sign-in">
# <a class="" href="/login">Sign In</a>
# </li>
# <li class="post-job-button">
# <a class="btn btn-secondary btn-boldblue" href="/post-new-job">Post Jobs</a>
# </li>
# <li class="submenu closed logged-out">
# <a class="toggle-main-menu closed" href="#">
# <span class="closed">
# <i class="fa fa-bars"></i>
# </span>
# <span class="open">
# <i class="fas fa-chevron-up"></i>
# </span>
# </a>
# <ul>
# <li class="text">
# <h4>Job Seekers</h4>
# </li>
# <li>
# <a href="/job-listings">Search Jobs <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a href="/job-notifications">Job Alerts <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a href="/login_post_resume">Post Resume <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="divider"></li>
# <li class="text">
# <h4>Employers</h4>
# </li>
# <li>
# <a href="/post-new-job">Post a Job <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a href="/employers/resume-search">Search Resumes <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="divider"></li>
# <li class="text">
# <h4>Resources</h4>
# </li>
# <li class="d-none d-md-block">
# <a class="item" href="/awards-contests">Awards/Contests <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a class="item" href="/career-advice">Career Advice <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="d-none d-md-block">
# <a class="item" href="/fellowship_listings">Fellowship Listings <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="d-none d-md-block">
# <a class="item" href="/journalism-schools">Journalism Schools <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="divider"></li>
# <li class="text">
# <h3>Registered Users</h3>
# <div class="d-none d-md-block">Already have an account?</div>
# </li>
# <li class="sign-in">
# <a href="/login">Login <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# </ul>
# </li> </ul>
# </nav>
# <div data-controller="symfony--ux-react--react" data-symfony--ux-react--react-component-value="modals/JobAlertsModal" data-symfony--ux-react--react-props-value='{"industries":[{"id":1,"industry":"Newspapers"},{"id":2,"industry":"Television"},{"id":5,"industry":"Digital Media"},{"id":3,"industry":"Radio"},{"id":4,"industry":"Magazines \/ Publishing"},{"id":13,"industry":"Nonprofit"},{"id":7,"industry":"Academia"},{"id":8,"industry":"Government"},{"id":14,"industry":"Financial Institutions"},{"id":12,"industry":"Newsletters"},{"id":6,"industry":"Public Relations"},{"id":10,"industry":"Trade Publications"},{"id":15,"industry":"Technology Sector"},{"id":11,"industry":"Other"}],"submitUrl":"\/job-notifications\/signup","recaptchaKey":"6LdNo7EUAAAAAHj9p_dV4PesXdqCALRDBIheN3Fr","user":false}'></div>
# <nav class="mobile">
# <ul>
# <li class="spacer"></li>
# <li class="submenu closed logged-out">
# <a class="toggle-main-menu closed" href="#">
# <span class="closed">
# <i class="fa fa-bars"></i>
# </span>
# <span class="open">
# <i class="fas fa-chevron-up"></i>
# </span>
# </a>
# <ul>
# <li class="text">
# <h4>Job Seekers</h4>
# </li>
# <li>
# <a href="/job-listings">Search Jobs <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a href="/job-notifications">Job Alerts <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a href="/login_post_resume">Post Resume <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="divider"></li>
# <li class="text">
# <h4>Employers</h4>
# </li>
# <li>
# <a href="/post-new-job">Post a Job <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a href="/employers/resume-search">Search Resumes <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="divider"></li>
# <li class="text">
# <h4>Resources</h4>
# </li>
# <li class="d-none d-md-block">
# <a class="item" href="/awards-contests">Awards/Contests <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li>
# <a class="item" href="/career-advice">Career Advice <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="d-none d-md-block">
# <a class="item" href="/fellowship_listings">Fellowship Listings <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="d-none d-md-block">
# <a class="item" href="/journalism-schools">Journalism Schools <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# <li class="divider"></li>
# <li class="text">
# <h3>Registered Users</h3>
# <div class="d-none d-md-block">Already have an account?</div>
# </li>
# <li class="sign-in">
# <a href="/login">Login <span class="arrow"><i class="fa fa-chevron-right"></i></span></a>
# </li>
# </ul>
# </li> </ul>
# </nav> </header>
# </div>
# </div>
# <div class="container">
# </div>
# <div class="container-fluid container-fluid-xl" id="jobs">
# <div class="m-2" style="padding-top: 8px;"></div>
# <div class="float-right d-lg-none">
# <button class="btn btn-primary btn-sm" id="filter-results">Filter Results</button>
# </div>
# <div class="m-4 d-none d-lg-block"></div>
# <div class="clearfix"></div>
# <div class="d-lg-none m-4"></div>
# <div class="jobs-page-wrapper">
# <div class="search-block">
# <div class="search-container">
# <h3>
#                     Refine Your Search
#                 </h3>
# <div class="row">
# <div class="col-sm-12">
# <input class="form-control" id="keywords" placeholder="e.g. Editor" style="border: 2px solid #CCCCCC;" type="text" value=""/>
# </div>
# </div>
# <div class="text-center" style="padding: 0 12.5%">
# <button class="btn btn-primary btn-block text-light" onclick="changeKeywords()" style="font-size: 17px;" type="button">
# <i class="fa fa-chevron-right"></i>
#                         Search Jobs
#                     </button>
# </div>
# <div class="m-3"></div>
# <div class="panel browse open">
# <div class="section always-open">
# <h4>Industries</h4>
# <div class="options industries">
# <div class="checkbox-list">
# <span><input checked="" data-id="1" id="industry-1" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="1"/></span>
# <span><a onclick="changeIndustryId(1)">Newspapers </a></span>
# </div>
# <div class="checkbox-list">
# <span><input checked="" data-id="2" id="industry-2" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="2"/></span>
# <span><a onclick="changeIndustryId(2)">Television </a></span>
# </div>
# <div class="checkbox-list">
# <span><input checked="" data-id="5" id="industry-5" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="5"/></span>
# <span><a onclick="changeIndustryId(5)">Digital Media </a></span>
# </div>
# <div class="checkbox-list">
# <span><input checked="" data-id="3" id="industry-3" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="3"/></span>
# <span><a onclick="changeIndustryId(3)">Radio </a></span>
# </div>
# <div class="checkbox-list">
# <span><input checked="" data-id="4" id="industry-4" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="4"/></span>
# <span><a onclick="changeIndustryId(4)">Magazines / Publishing </a></span>
# </div>
# <div class="checkbox-list">
# <span><input checked="" data-id="13" id="industry-13" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="13"/></span>
# <span><a onclick="changeIndustryId(13)">Nonprofit </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input checked="" data-id="7" id="industry-7" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="7"/></span>
# <span><a onclick="changeIndustryId(7)">Academia </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input checked="" data-id="8" id="industry-8" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="8"/></span>
# <span><a onclick="changeIndustryId(8)">Government </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input checked="" data-id="14" id="industry-14" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="14"/></span>
# <span><a onclick="changeIndustryId(14)">Financial Institutions </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input checked="" data-id="12" id="industry-12" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="12"/></span>
# <span><a onclick="changeIndustryId(12)">Newsletters </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input checked="" data-id="6" id="industry-6" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="6"/></span>
# <span><a onclick="changeIndustryId(6)">Public Relations </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input checked="" data-id="11" id="industry-11" name="industries[]" onclick="toggleIndustry($(this))" type="checkbox" value="11"/></span>
# <span><a onclick="changeIndustryId(11)">Other </a></span>
# </div>
# <div class="checkbox-list checkbox-list-hidden">
# <span><input name="diversity" onclick="toggleDiversity();" type="checkbox" value="1"/></span>
# <span><a onclick="toggleDiversity();">Diversity Jobs</a></span>
# </div>
# <a class="see-more-industries" href="#"><i class="fas fa-caret-down"></i> see more industries</a>
# <a class="hide-more-industries" href="#" style="display: none;"><i class="fas fa-caret-up"></i> see less industries</a>
# </div>
# </div>
# <div class="section">
# <h4>
# <span>Position</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <ul class="options">
# <li>
# <a data-position="1" onclick="changePositionId(1)">
#                                             Academia
#                                         </a>
# </li>
# <li>
# <a data-position="3" onclick="changePositionId(3)">
#                                             Administration
#                                         </a>
# </li>
# <li>
# <a data-position="862" onclick="changePositionId(862)">
#                                             Advertising Director
#                                         </a>
# </li>
# <li>
# <a data-position="829" onclick="changePositionId(829)">
#                                             Anchor
#                                         </a>
# </li>
# <li>
# <a data-position="101" onclick="changePositionId(101)">
#                                             Art Director
#                                         </a>
# </li>
# <li>
# <a data-position="853" onclick="changePositionId(853)">
#                                             Assignment Editor
#                                         </a>
# </li>
# <li>
# <a data-position="861" onclick="changePositionId(861)">
#                                             Awards
#                                         </a>
# </li>
# <li>
# <a data-position="846" onclick="changePositionId(846)">
#                                             Blogger
#                                         </a>
# </li>
# <li>
# <a data-position="806" onclick="changePositionId(806)">
#                                             Booker
#                                         </a>
# </li>
# <li>
# <a data-position="849" onclick="changePositionId(849)">
#                                             Camera Operator
#                                         </a>
# </li>
# <li>
# <a data-position="836" onclick="changePositionId(836)">
#                                             Digital Director
#                                         </a>
# </li>
# <li>
# <a data-position="12" onclick="changePositionId(12)">
#                                             Circulation
#                                         </a>
# </li>
# <li>
# <a data-position="85" onclick="changePositionId(85)">
#                                             Communications/Public Affairs
#                                         </a>
# </li>
# <li>
# <a data-position="13" onclick="changePositionId(13)">
#                                             Copy Editor
#                                         </a>
# </li>
# <li>
# <a data-position="18" onclick="changePositionId(18)">
#                                             Copywriter
#                                         </a>
# </li>
# <li>
# <a data-position="822" onclick="changePositionId(822)">
#                                             Design Editor
#                                         </a>
# </li>
# <li>
# <a data-position="15" onclick="changePositionId(15)">
#                                             Director
#                                         </a>
# </li>
# <li>
# <a data-position="16" onclick="changePositionId(16)">
#                                             Editor
#                                         </a>
# </li>
# <li>
# <a data-position="17" onclick="changePositionId(17)">
#                                             Editorial Assistant
#                                         </a>
# </li>
# <li>
# <a data-position="92" onclick="changePositionId(92)">
#                                             Engineer
#                                         </a>
# </li>
# <li>
# <a data-position="842" onclick="changePositionId(842)">
#                                             Executive Director
#                                         </a>
# </li>
# <li>
# <a data-position="22" onclick="changePositionId(22)">
#                                             Executive Producer
#                                         </a>
# </li>
# <li>
# <a data-position="805" onclick="changePositionId(805)">
#                                             Fellowship
#                                         </a>
# </li>
# <li>
# <a data-position="866" onclick="changePositionId(866)">
#                                             Fundraising
#                                         </a>
# </li>
# <li>
# <a data-position="803" onclick="changePositionId(803)">
#                                             General Manager
#                                         </a>
# </li>
# <li>
# <a data-position="838" onclick="changePositionId(838)">
#                                             Graphic Designer
#                                         </a>
# </li>
# <li>
# <a data-position="82" onclick="changePositionId(82)">
#                                             Internship
#                                         </a>
# </li>
# <li>
# <a data-position="25" onclick="changePositionId(25)">
#                                             Marketing
#                                         </a>
# </li>
# <li>
# <a data-position="808" onclick="changePositionId(808)">
#                                             Master Control Operator
#                                         </a>
# </li>
# <li>
# <a data-position="26" onclick="changePositionId(26)">
#                                             Media Relations
#                                         </a>
# </li>
# <li>
# <a data-position="834" onclick="changePositionId(834)">
#                                             Meteorologist
#                                         </a>
# </li>
# <li>
# <a data-position="28" onclick="changePositionId(28)">
#                                             News Director
#                                         </a>
# </li>
# <li>
# <a data-position="112" onclick="changePositionId(112)">
#                                             On-Air Talent
#                                         </a>
# </li>
# <li>
# <a data-position="35" onclick="changePositionId(35)">
#                                             Operations
#                                         </a>
# </li>
# <li>
# <a data-position="63" onclick="changePositionId(63)">
#                                             Other
#                                         </a>
# </li>
# <li>
# <a data-position="802" onclick="changePositionId(802)">
#                                             Page Designer
#                                         </a>
# </li>
# <li>
# <a data-position="855" onclick="changePositionId(855)">
#                                             Paginator
#                                         </a>
# </li>
# <li>
# <a data-position="108" onclick="changePositionId(108)">
#                                             Photo Editor
#                                         </a>
# </li>
# <li>
# <a data-position="37" onclick="changePositionId(37)">
#                                             Photographer
#                                         </a>
# </li>
# <li>
# <a data-position="859" onclick="changePositionId(859)">
#                                             Press Secretary
#                                         </a>
# </li>
# <li>
# <a data-position="38" onclick="changePositionId(38)">
#                                             Producer
#                                         </a>
# </li>
# <li>
# <a data-position="39" onclick="changePositionId(39)">
#                                             Production Editor
#                                         </a>
# </li>
# <li>
# <a data-position="824" onclick="changePositionId(824)">
#                                             Production Assistant
#                                         </a>
# </li>
# <li>
# <a data-position="833" onclick="changePositionId(833)">
#                                             Production Manager
#                                         </a>
# </li>
# <li>
# <a data-position="43" onclick="changePositionId(43)">
#                                             Promotions/Publicity
#                                         </a>
# </li>
# <li>
# <a data-position="73" onclick="changePositionId(73)">
#                                             Proofreader
#                                         </a>
# </li>
# <li>
# <a data-position="44" onclick="changePositionId(44)">
#                                             Public Relations
#                                         </a>
# </li>
# <li>
# <a data-position="94" onclick="changePositionId(94)">
#                                             Publicist
#                                         </a>
# </li>
# <li>
# <a data-position="50" onclick="changePositionId(50)">
#                                             Publisher
#                                         </a>
# </li>
# <li>
# <a data-position="95" onclick="changePositionId(95)">
#                                             Reporter
#                                         </a>
# </li>
# <li>
# <a data-position="52" onclick="changePositionId(52)">
#                                             Researcher
#                                         </a>
# </li>
# <li>
# <a data-position="847" onclick="changePositionId(847)">
#                                             Sales
#                                         </a>
# </li>
# <li>
# <a data-position="77" onclick="changePositionId(77)">
#                                             Station Manager
#                                         </a>
# </li>
# <li>
# <a data-position="856" onclick="changePositionId(856)">
#                                             Student Media Advisor
#                                         </a>
# </li>
# <li>
# <a data-position="850" onclick="changePositionId(850)">
#                                             Tape Editor
#                                         </a>
# </li>
# <li>
# <a data-position="59" onclick="changePositionId(59)">
#                                             Technical Writer/Editor
#                                         </a>
# </li>
# <li>
# <a data-position="800" onclick="changePositionId(800)">
#                                             Training / Workshop
#                                         </a>
# </li>
# <li>
# <a data-position="863" onclick="changePositionId(863)">
#                                             Video Journalist
#                                         </a>
# </li>
# <li>
# <a data-position="54" onclick="changePositionId(54)">
#                                             Video/Tape Editor
#                                         </a>
# </li>
# <li>
# <a data-position="96" onclick="changePositionId(96)">
#                                             Videographer
#                                         </a>
# </li>
# <li>
# <a data-position="865" onclick="changePositionId(865)">
#                                             Web Producer
#                                         </a>
# </li>
# <li>
# <a data-position="827" onclick="changePositionId(827)">
#                                             Writer
#                                         </a>
# </li>
# </ul>
# </div>
# <div class="section">
# <h4>
# <span>State</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <ul class="options location-options">
# <li>
# <a data-location="2" onclick="changeLocationId(2);">
#                                         Alabama                                     </a>
# </li>
# <li>
# <a data-location="1" onclick="changeLocationId(1);">
#                                         Alaska                                     </a>
# </li>
# <li>
# <a data-location="51" onclick="changeLocationId(51);">
#                                         American Samoa                                     </a>
# </li>
# <li>
# <a data-location="3" onclick="changeLocationId(3);">
#                                         Arizona                                     </a>
# </li>
# <li>
# <a data-location="50" onclick="changeLocationId(50);">
#                                         Arkansas                                     </a>
# </li>
# <li>
# <a data-location="4" onclick="changeLocationId(4);">
#                                         California                                     </a>
# </li>
# <li>
# <a data-location="5" onclick="changeLocationId(5);">
#                                         Colorado                                     </a>
# </li>
# <li>
# <a data-location="6" onclick="changeLocationId(6);">
#                                         Connecticut                                     </a>
# </li>
# <li>
# <a data-location="8" onclick="changeLocationId(8);">
#                                         Delaware                                     </a>
# </li>
# <li>
# <a data-location="7" onclick="changeLocationId(7);">
#                                         District of Columbia                                     </a>
# </li>
# <li style="display: none">
# <a data-location="9" onclick="changeLocationId(9);">
#                                         Florida                                     </a>
# </li>
# <li style="display: none">
# <a data-location="10" onclick="changeLocationId(10);">
#                                         Georgia                                     </a>
# </li>
# <li style="display: none">
# <a data-location="45" onclick="changeLocationId(45);">
#                                         Hawaii                                     </a>
# </li>
# <li style="display: none">
# <a data-location="12" onclick="changeLocationId(12);">
#                                         Idaho                                     </a>
# </li>
# <li style="display: none">
# <a data-location="46" onclick="changeLocationId(46);">
#                                         Illinois                                     </a>
# </li>
# <li style="display: none">
# <a data-location="13" onclick="changeLocationId(13);">
#                                         Indiana                                     </a>
# </li>
# <li style="display: none">
# <a data-location="11" onclick="changeLocationId(11);">
#                                         Iowa                                     </a>
# </li>
# <li style="display: none">
# <a data-location="47" onclick="changeLocationId(47);">
#                                         Kansas                                     </a>
# </li>
# <li style="display: none">
# <a data-location="14" onclick="changeLocationId(14);">
#                                         Kentucky                                     </a>
# </li>
# <li style="display: none">
# <a data-location="15" onclick="changeLocationId(15);">
#                                         Louisiana                                     </a>
# </li>
# <li style="display: none">
# <a data-location="48" onclick="changeLocationId(48);">
#                                         Maine                                     </a>
# </li>
# <li style="display: none">
# <a data-location="52" onclick="changeLocationId(52);">
#                                         Marshall Islands                                     </a>
# </li>
# <li style="display: none">
# <a data-location="17" onclick="changeLocationId(17);">
#                                         Maryland                                     </a>
# </li>
# <li style="display: none">
# <a data-location="16" onclick="changeLocationId(16);">
#                                         Massachusetts                                     </a>
# </li>
# <li style="display: none">
# <a data-location="18" onclick="changeLocationId(18);">
#                                         Michigan                                     </a>
# </li>
# <li style="display: none">
# <a data-location="19" onclick="changeLocationId(19);">
#                                         Minnesota                                     </a>
# </li>
# <li style="display: none">
# <a data-location="21" onclick="changeLocationId(21);">
#                                         Mississippi                                     </a>
# </li>
# <li style="display: none">
# <a data-location="20" onclick="changeLocationId(20);">
#                                         Missouri                                     </a>
# </li>
# <li style="display: none">
# <a data-location="22" onclick="changeLocationId(22);">
#                                         Montana                                     </a>
# </li>
# <li style="display: none">
# <a data-location="25" onclick="changeLocationId(25);">
#                                         Nebraska                                     </a>
# </li>
# <li style="display: none">
# <a data-location="29" onclick="changeLocationId(29);">
#                                         Nevada                                     </a>
# </li>
# <li style="display: none">
# <a data-location="26" onclick="changeLocationId(26);">
#                                         New Hampshire                                     </a>
# </li>
# <li style="display: none">
# <a data-location="27" onclick="changeLocationId(27);">
#                                         New Jersey                                     </a>
# </li>
# <li style="display: none">
# <a data-location="28" onclick="changeLocationId(28);">
#                                         New Mexico                                     </a>
# </li>
# <li style="display: none">
# <a data-location="53" onclick="changeLocationId(53);">
#                                         New York                                     </a>
# </li>
# <li style="display: none">
# <a data-location="23" onclick="changeLocationId(23);">
#                                         North Carolina                                     </a>
# </li>
# <li style="display: none">
# <a data-location="24" onclick="changeLocationId(24);">
#                                         North Dakota                                     </a>
# </li>
# <li style="display: none">
# <a data-location="30" onclick="changeLocationId(30);">
#                                         Ohio                                     </a>
# </li>
# <li style="display: none">
# <a data-location="31" onclick="changeLocationId(31);">
#                                         Oklahoma                                     </a>
# </li>
# <li style="display: none">
# <a data-location="32" onclick="changeLocationId(32);">
#                                         Oregon                                     </a>
# </li>
# <li style="display: none">
# <a data-location="54" onclick="changeLocationId(54);">
#                                         Palau                                     </a>
# </li>
# <li style="display: none">
# <a data-location="33" onclick="changeLocationId(33);">
#                                         Pennsylvania                                     </a>
# </li>
# <li style="display: none">
# <a data-location="55" onclick="changeLocationId(55);">
#                                         Puerto Rico                                     </a>
# </li>
# <li style="display: none">
# <a data-location="34" onclick="changeLocationId(34);">
#                                         Rhode Island                                     </a>
# </li>
# <li style="display: none">
# <a data-location="35" onclick="changeLocationId(35);">
#                                         South Carolina                                     </a>
# </li>
# <li style="display: none">
# <a data-location="36" onclick="changeLocationId(36);">
#                                         South Dakota                                     </a>
# </li>
# <li style="display: none">
# <a data-location="37" onclick="changeLocationId(37);">
#                                         Tennessee                                     </a>
# </li>
# <li style="display: none">
# <a data-location="49" onclick="changeLocationId(49);">
#                                         Texas                                     </a>
# </li>
# <li style="display: none">
# <a data-location="38" onclick="changeLocationId(38);">
#                                         Utah                                     </a>
# </li>
# <li style="display: none">
# <a data-location="40" onclick="changeLocationId(40);">
#                                         Vermont                                     </a>
# </li>
# <li style="display: none">
# <a data-location="56" onclick="changeLocationId(56);">
#                                         Virgin Islands                                     </a>
# </li>
# <li style="display: none">
# <a data-location="39" onclick="changeLocationId(39);">
#                                         Virginia                                     </a>
# </li>
# <li style="display: none">
# <a data-location="41" onclick="changeLocationId(41);">
#                                         Washington                                     </a>
# </li>
# <li style="display: none">
# <a data-location="43" onclick="changeLocationId(43);">
#                                         West Virginia                                     </a>
# </li>
# <li style="display: none">
# <a data-location="42" onclick="changeLocationId(42);">
#                                         Wisconsin                                     </a>
# </li>
# <li style="display: none">
# <a data-location="44" onclick="changeLocationId(44);">
#                                         Wyoming                                     </a>
# </li>
# <li style="display: none">
# <a data-location="64" onclick="changeLocationId(64);">
#                                         Telecommute                                     </a>
# </li>
# <li style="display: none">
# <a data-location="57" onclick="changeLocationId(57);">
#                                         Other                                     </a>
# </li>
# <li style="display: none">
# <a data-location="58" onclick="changeLocationId(58);">
#                                         Africa                                     </a>
# </li>
# <li style="display: none">
# <a data-location="59" onclick="changeLocationId(59);">
#                                         Asia                                     </a>
# </li>
# <li style="display: none">
# <a data-location="69" onclick="changeLocationId(69);">
#                                         Australia                                     </a>
# </li>
# <li style="display: none">
# <a data-location="62" onclick="changeLocationId(62);">
#                                         Canada                                     </a>
# </li>
# <li style="display: none">
# <a data-location="60" onclick="changeLocationId(60);">
#                                         Central America                                     </a>
# </li>
# <li style="display: none">
# <a data-location="61" onclick="changeLocationId(61);">
#                                         Europe                                     </a>
# </li>
# <li style="display: none">
# <a data-location="71" onclick="changeLocationId(71);">
#                                         Guam                                     </a>
# </li>
# <li style="display: none">
# <a data-location="103" onclick="changeLocationId(103);">
#                                         Mariana Islands                                     </a>
# </li>
# <li style="display: none">
# <a data-location="102" onclick="changeLocationId(102);">
#                                         Mexico                                     </a>
# </li>
# <li style="display: none">
# <a data-location="68" onclick="changeLocationId(68);">
#                                         Middle East                                     </a>
# </li>
# <li style="display: none">
# <a data-location="63" onclick="changeLocationId(63);">
#                                         South America                                     </a>
# </li>
# <li style="display: none">
# <a data-location="70" onclick="changeLocationId(70);">
#                                         United States                                     </a>
# </li>
# <li style="display: none">
# <a data-location="101" onclick="changeLocationId(101);">
#                                         All Locations                                     </a>
# </li>
# <li class="location-show-more"><a href="#"><i class="fas fa-caret-down"></i> see more locations</a></li>
# </ul>
# </div>
# <div class="section">
# <h4>
# <span>Job Type</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <ul class="options">
# <li>
# <a data-job-type="2" onclick="changeJobTypeId(2);">
#                                             Full-time                                         </a>
# </li>
# <li>
# <a data-job-type="3" onclick="changeJobTypeId(3);">
#                                             Part-time                                         </a>
# </li>
# <li>
# <a data-job-type="4" onclick="changeJobTypeId(4);">
#                                             Freelance                                         </a>
# </li>
# <li>
# <a data-job-type="8" onclick="changeJobTypeId(8);">
#                                             Telecommute                                         </a>
# </li>
# <li>
# <a data-job-type="5" onclick="changeJobTypeId(5);">
#                                             Temporary                                         </a>
# </li>
# <li>
# <a data-job-type="6" onclick="changeJobTypeId(6);">
#                                             Intern                                         </a>
# </li>
# </ul>
# </div>
# <div class="section">
# <h4>
# <span>Telecommute</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <ul class="options">
# <li><a data-virtual="1" onclick="changeVirtual(1);">Yes</a></li>
# <li><a data-virtual="0" onclick="changeVirtual(0);">No</a></li>
# </ul>
# </div>
# <div class="section">
# <h4>
# <span>Date Posted</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <ul class="options">
# <li><a data-date="days7" onclick="changeDateId('days7');">Last 7 Days </a></li>
# <li><a data-date="days14" onclick="changeDateId('days14');">Last 14 Days </a></li>
# <li><a data-date="days30" onclick="changeDateId('days30');">Last 30 days </a></li>
# </ul>
# </div>
# </div>
# <div class="panel detailed">
# <div class="section open always-open">
# <h4>Industry</h4>
# <div class="options industries">
# <select class="form-control options" id="location" onchange="changeIndustryId($(this).val(), false)">
# <option value="">Select All</option>
# <option value="1">Newspapers</option>
# <option value="2">Television</option>
# <option value="5">Digital Media</option>
# <option value="3">Radio</option>
# <option value="4">Magazines / Publishing</option>
# <option value="13">Nonprofit</option>
# <option value="7">Academia</option>
# <option value="8">Government</option>
# <option value="14">Financial Institutions</option>
# <option value="12">Newsletters</option>
# <option value="6">Public Relations</option>
# <option value="10">Trade Publications</option>
# <option value="15">Technology Sector</option>
# <option value="11">Other</option>
# </select>
# </div>
# </div>
# <div class="section">
# <h4>
# <span>Position</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <select class="form-control options" id="location" onchange="changePositionId($(this).val(), false)">
# <option value="">Select All</option>
# <option value="1">Academia</option>
# <option value="3">Administration</option>
# <option value="862">Advertising Director</option>
# <option value="829">Anchor</option>
# <option value="101">Art Director</option>
# <option value="853">Assignment Editor</option>
# <option value="861">Awards</option>
# <option value="846">Blogger</option>
# <option value="806">Booker</option>
# <option value="849">Camera Operator</option>
# <option value="836">Digital Director</option>
# <option value="12">Circulation</option>
# <option value="85">Communications/Public Affairs</option>
# <option value="13">Copy Editor</option>
# <option value="18">Copywriter</option>
# <option value="822">Design Editor</option>
# <option value="15">Director</option>
# <option value="16">Editor</option>
# <option value="17">Editorial Assistant</option>
# <option value="92">Engineer</option>
# <option value="842">Executive Director</option>
# <option value="22">Executive Producer</option>
# <option value="805">Fellowship</option>
# <option value="866">Fundraising</option>
# <option value="803">General Manager</option>
# <option value="838">Graphic Designer</option>
# <option value="82">Internship</option>
# <option value="25">Marketing</option>
# <option value="808">Master Control Operator</option>
# <option value="26">Media Relations</option>
# <option value="834">Meteorologist</option>
# <option value="28">News Director</option>
# <option value="112">On-Air Talent</option>
# <option value="35">Operations</option>
# <option value="63">Other</option>
# <option value="802">Page Designer</option>
# <option value="855">Paginator</option>
# <option value="108">Photo Editor</option>
# <option value="37">Photographer</option>
# <option value="859">Press Secretary</option>
# <option value="38">Producer</option>
# <option value="39">Production Editor</option>
# <option value="824">Production Assistant</option>
# <option value="833">Production Manager</option>
# <option value="43">Promotions/Publicity</option>
# <option value="73">Proofreader</option>
# <option value="44">Public Relations</option>
# <option value="94">Publicist</option>
# <option value="50">Publisher</option>
# <option value="95">Reporter</option>
# <option value="52">Researcher</option>
# <option value="847">Sales</option>
# <option value="77">Station Manager</option>
# <option value="856">Student Media Advisor</option>
# <option value="850">Tape Editor</option>
# <option value="59">Technical Writer/Editor</option>
# <option value="800">Training / Workshop</option>
# <option value="863">Video Journalist</option>
# <option value="54">Video/Tape Editor</option>
# <option value="96">Videographer</option>
# <option value="865">Web Producer</option>
# <option value="827">Writer</option>
# </select>
# </div>
# <div class="section">
# <h4>
# <span>State</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <select class="form-control options" id="location" onchange="changeLocationId($(this).val(), false)">
# <option value="0">Select All</option>
# <option value="2">Alabama</option>
# <option value="1">Alaska</option>
# <option value="51">American Samoa</option>
# <option value="3">Arizona</option>
# <option value="50">Arkansas</option>
# <option value="4">California</option>
# <option value="5">Colorado</option>
# <option value="6">Connecticut</option>
# <option value="8">Delaware</option>
# <option value="7">District of Columbia</option>
# <option value="9">Florida</option>
# <option value="10">Georgia</option>
# <option value="45">Hawaii</option>
# <option value="12">Idaho</option>
# <option value="46">Illinois</option>
# <option value="13">Indiana</option>
# <option value="11">Iowa</option>
# <option value="47">Kansas</option>
# <option value="14">Kentucky</option>
# <option value="15">Louisiana</option>
# <option value="48">Maine</option>
# <option value="52">Marshall Islands</option>
# <option value="17">Maryland</option>
# <option value="16">Massachusetts</option>
# <option value="18">Michigan</option>
# <option value="19">Minnesota</option>
# <option value="21">Mississippi</option>
# <option value="20">Missouri</option>
# <option value="22">Montana</option>
# <option value="25">Nebraska</option>
# <option value="29">Nevada</option>
# <option value="26">New Hampshire</option>
# <option value="27">New Jersey</option>
# <option value="28">New Mexico</option>
# <option value="53">New York</option>
# <option value="23">North Carolina</option>
# <option value="24">North Dakota</option>
# <option value="30">Ohio</option>
# <option value="31">Oklahoma</option>
# <option value="32">Oregon</option>
# <option value="54">Palau</option>
# <option value="33">Pennsylvania</option>
# <option value="55">Puerto Rico</option>
# <option value="34">Rhode Island</option>
# <option value="35">South Carolina</option>
# <option value="36">South Dakota</option>
# <option value="37">Tennessee</option>
# <option value="49">Texas</option>
# <option value="38">Utah</option>
# <option value="40">Vermont</option>
# <option value="56">Virgin Islands</option>
# <option value="39">Virginia</option>
# <option value="41">Washington</option>
# <option value="43">West Virginia</option>
# <option value="42">Wisconsin</option>
# <option value="44">Wyoming</option>
# <option value="64">Telecommute</option>
# <option value="57">Other</option>
# <option value="58">Africa</option>
# <option value="59">Asia</option>
# <option value="69">Australia</option>
# <option value="62">Canada</option>
# <option value="60">Central America</option>
# <option value="61">Europe</option>
# <option value="71">Guam</option>
# <option value="103">Mariana Islands</option>
# <option value="102">Mexico</option>
# <option value="68">Middle East</option>
# <option value="63">South America</option>
# <option value="70">United States</option>
# <option value="101">All Locations</option>
# </select>
# </div>
# <div class="section">
# <h4>
# <span>Job Type</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <select class="form-control options" id="location" onchange="changeJobTypeId($(this).val(), false)">
# <option value="">Select All</option>
# <option value="2">Full-time</option>
# <option value="3">Part-time</option>
# <option value="4">Freelance</option>
# <option value="8">Telecommute</option>
# <option value="5">Temporary</option>
# <option value="6">Intern</option>
# <option value="7">Unpaid</option>
# </select>
# </div>
# <div class="section">
# <h4>
# <span>Telecommute</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <select class="form-control options" id="location" onchange="changeVirtual($(this).val(), false)">
# <option value="1">Yes</option>
# <option selected="" value="0">No</option>
# </select>
# </div>
# <div class="section">
# <h4>
# <span>Salary</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <select class="form-control options" id="location" onchange="changeSalaryId($(this).val(), false)">
# <option value="">Select All</option>
# <option value="29">Unpaid</option>
# <option value="8">Negotiable</option>
# <option value="1">Up to $15,000</option>
# <option value="2">$15,000 to $20,000</option>
# <option value="15">$20,000 to $25,000</option>
# <option value="14">$25,000 to $30,000</option>
# <option value="3">$30,000 to $35,000</option>
# <option value="19">$35,000 to $40,000</option>
# <option value="17">$40,000 to $45,000</option>
# <option value="4">$45,000 to $50,000</option>
# <option value="18">$50,000 to $55,000</option>
# <option value="5">$55,000 to $60,000</option>
# <option value="6">$60,000 to $65,000</option>
# <option value="11">$65,000 to $70,000</option>
# <option value="12">$70,000 to $75,000</option>
# <option value="9">$75,000 to $80,000</option>
# <option value="10">$80,000 to $85,000</option>
# <option value="20">$85,000 to $90,000</option>
# <option value="21">$90,000 to $100,000</option>
# <option value="22">$100,000 to $120,000</option>
# <option value="23">$120,000 to $140,000</option>
# <option value="24">$140,000 to $160,000</option>
# <option value="25">$160,000 to $180,000</option>
# <option value="26">$180,000 to $200,000</option>
# <option value="27">$200,000 to $250,000</option>
# <option value="28">More Than $250,000</option>
# </select>
# </div>
# <div class="section">
# <h4>
# <span>Date Posted</span>
# <span><i class="fal fa-plus-square"></i><i class="fal fa-minus-square"></i></span>
# </h4>
# <select class="form-control options" id="location" onchange="changeDateId($(this).val(), false)">
# <option value="">Select All</option>
# <option value="days7">Last 7 Days </option>
# <option value="days14">Last 14 Days </option>
# <option value="days30">Last 30 days </option>
# </select>
# </div>
# <div class="text-center">
# <div class="m-4"></div>
# <button class="btn btn-primary" onclick="changeKeywords()" type="button"><i class="fa fa-chevron-right"></i> Search</button>
# </div>
# </div>
# ...
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body text-center">
# <h5>Create an Account to Save This Job</h5>
# <div class="form-errors text-danger" style="display: none; margin-top: 15px;"></div>
# <div class="mb-3 text-left" style="max-width: 350px; margin: 20px auto;">
# <label for="jobBasketModal-name">Your Name</label>
# <input class="form-control" id="jobBasketModal-name" placeholder="Your Name" style="border-radius: 5px !important;" type="text"/>
# <label for="jobBasketModal-email">Your Email</label>
# <input class="form-control" id="jobBasketModal-email" placeholder="name@example.com" style="border-radius: 5px !important;" type="email"/>
# <label for="jobBasketModal-password">Create Password</label>
# <input class="form-control" id="jobBasketModal-password" placeholder="Password" style="border-radius: 5px !important;" type="password"/>
# <button class="btn btn-blue btn-lg btn-block" id="jobBasketModal-submit" style="position: relative; margin-top: 30px; border-radius: 25px !important;" type="submit">
# <div class="spinner-border text-primary" role="status" style="position: absolute; left: 10px; display: none;">
# <span class="sr-only">Loading...</span>
# </div>
#                         Create Account
#                     </button>
# <p class="mb-3 text-muted" style="font-size:14px; margin-top: 30px;">
#                         By continuing, you are agreeing with <strong>JournalismJobs.com's</strong>
# <a href="/privacy_policy">Privacy Policy</a> and
#                         <a href="/terms_and_conditions">Terms of Use</a>.
#                     </p>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# <footer>
# <div class="container footer">
# <div class="footer-grid">
# <div class="footer-column">
# <h3>Job Seekers</h3>
# <ul>
# <li>
# <a href="/job-listings"><i class="fal fa-fw fa-chevron-right"></i> Find a Job</a>
# </li>
# <li>
# <a href="/job-notifications"><i class="fal fa-fw fa-chevron-right"></i> Job Alerts</a>
# </li>
# <li>
# <a href="/login_post_resume"><i class="fal fa-fw fa-chevron-right"></i> Post a Resume</a>
# </li>
# <li>
# <a href="/job-seeker/"><i class="fal fa-fw fa-chevron-right"></i> Account Login</a>
# </li>
# </ul>
# <div class="m-3 d-lg-none"></div>
# </div>
# <div class="footer-column">
# <h3>Employers</h3>
# <ul>
# <li>
# <a href="/register"><i class="fal fa-fw fa-chevron-right"></i> Register</a>
# </li>
# <li>
# <a href="/post-new-job"><i class="fal fa-fw fa-chevron-right"></i> Post a Job</a>
# </li>
# <li>
# <a href="/employers/resume-search"><i class="fal fa-fw fa-chevron-right"></i> Search Resumes</a>
# </li>
# <li>
# <a href="/advertising"><i class="fal fa-fw fa-chevron-right"></i> Advertising</a>
# </li>
# <li>
# <a href="/login_employer"><i class="fal fa-fw fa-chevron-right"></i> Account Login</a>
# </li>
# </ul>
# <div class="m-3 d-lg-none"></div>
# </div>
# <div class="footer-column">
# <h3>Company</h3>
# <ul>
# <li>
# <a href="/about"><i class="fal fa-fw fa-chevron-right"></i> About Us</a>
# </li>
# <li>
# <a href="/privacy_policy"><i class="fal fa-fw fa-chevron-right"></i> Privacy Policy</a>
# </li>
# <li>
# <a href="/terms_and_conditions"><i class="fal fa-fw fa-chevron-right"></i> Terms and Conditions</a>
# </li>
# </ul>
# <div class="m-3 d-lg-none"></div>
# </div>
# <div class="footer-column">
# <h3>Contact</h3>
# <ul>
# <li>
# <a href="mailto:info@journalismjobs.com"><i class="fa fa-fw fa-envelope"></i> info@journalismjobs.com</a>
# </li>
# <li>
# <a href="javascript:;"><i class="fa fa-fw fa-phone"></i> 510-508-7386</a>
# </li>
# </ul>
# <div class="m-3 d-lg-none"></div>
# </div>
# <div class="footer-column footer-social">
# <h3>Social</h3>
# <ul>
# <li>
# <a href="https://www.facebook.com/pages/JournalismJobs/189821501048573" target="_blank"><i class="fab fa-fw fa-facebook-square"></i> Facebook</a>
# </li>
# <li>
# <a href="https://www.twitter.com/jjobs_tweets" target="_blank"><i class="fab fa-fw fa-twitter-square"></i> Twitter</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="copyright">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-lg-6">
#                     © 1998-2023 JournalismJobs.com All Rights Reserved.
#                 </div>
# <div class="col-sm-12 col-lg-6 text-right">
# <a href="http://www.newroadsmedia.com/" target="_blank"><img src="/images/newroadsmedia.jpg" style="height: 28px;"/></a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- Optional JavaScript -->
# <!-- jQuery first, then Popper.js, then Bootstrap JS -->
# <script src="https://code.jquery.com/jquery-3.3.1.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js"></script>
# <script src="//cdn.ckeditor.com/4.7.3/standard/ckeditor.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap-select@1.13.9/dist/js/bootstrap-select.min.js"></script>
# <script src="//www.google.com/recaptcha/api.js?hl=en"></script>
# <script defer="" src="/build/runtime.9a71ee5d.js"></script><script defer="" src="/build/app.02a14dc9.js"></script>
# <script>
#     $('.submenu a.toggle-main-menu').click(function(e) {
#         e.preventDefault();
#         var $this = $(this);
#         if ($(this).closest('.submenu').find('ul').is(':visible') === false) {
#             setTimeout(function () {
#                 $this.closest('.submenu').toggleClass('open').toggleClass('closed');
#                 $this.closest('body').toggleClass('open');
#             }, 10);
#         }
#     });
#     $('nav.mobile .submenu a.toggle-main-menu').click(function(e) {
#         e.preventDefault();
#         var $this = $(this);
#         if ($(this).closest('.submenu').find('ul').is(':visible') === true) {
#             setTimeout(function () {
#                 $this.closest('.submenu').toggleClass('open').toggleClass('closed');
#                 $this.closest('body').toggleClass('open');
#                 $('#top-banner').show();
#             }, 10);
#         } else {
#             $('#top-banner').hide();
#         }
#     });
#     $('body').click(function() {
#         if ($('nav.desktop .submenu').find('ul').is(':visible') === true) {
#             setTimeout(function () {
#                 $('.submenu ul:visible').closest('.submenu').removeClass('open').addClass('closed');
#             }, 10);
#         }
#     });
#
#     $('header a').click(function(e) {
#         if ($(this).attr('href') === '#') {
#             e.preventDefault();
#         }
#     })
# </script>
# <script>
#         var shouldValidateCaptcha = true;
#         var shouldValidateUser = true;
#         var locationId = "";
#         var jobTypeId = "";
#         var dateId = "";
#         var industryIds = [];
#         var keywords = "";
#         var diversity = "";
#         var positionId = "";
#         var focusId = "";
#         var salaryId = "";
#         var company = "";
#         var title = "";
#         var virtual = "";
#         var perPage = parseInt("100")
#
#                     industryIds.push(0);
#                     industryIds.push(1);
#                     industryIds.push(2);
#                     industryIds.push(5);
#                     industryIds.push(3);
#                     industryIds.push(4);
#                     industryIds.push(13);
#                     industryIds.push(7);
#                     industryIds.push(8);
#                     industryIds.push(14);
#                     industryIds.push(12);
#                     industryIds.push(6);
#                     industryIds.push(10);
#                     industryIds.push(15);
#                     industryIds.push(11);
#
#         var page = 1;
#
#         var buildUrl = function()
#         {
#             var industryIdsString = industryIds.join(",");
#
#             var parameters = {
#                 keywords: keywords,
#                 location: locationId,
#                 jobType: jobTypeId,
#                 date: dateId,
#                 industries: industryIdsString,
#                 position: positionId,
#                 diversity: diversity,
#                 focuses: focusId,
#                 salary: salaryId,
#                 company: company,
#                 title: title,
#                 virtual: virtual,
#                 page: page,
#                 count: perPage,
#             };
#
#             return '/job-listings?keywords=' + keywords + '&location=' + locationId + '&jobType=' + jobTypeId + '&date=' + dateId + '&industries=' + industryIdsString + '&position=' + positionId + '&diversity=' + diversity + '&focuses=' + focusId + '&salary=' + salaryId + '&company=' + company + '&title=' + title + '&virtual=' + virtual + '&page=' + page + '&count=' + perPage;
#             //return '?' + Object.keys(parameters).map(key => key + '=' + parameters[key]).join('&');
#         };
#
#         let $request = null
#         const setFilters = function(redirect = true, closeSearch = true, changePage = 1) {
#             if (redirect === false) {
#                 return;
#             }
#             if ($request != null) {
#                 $request.abort()
#                 $request = null
#             }
#             page = changePage
#             $('#jobs .main').html('<div class="text-center p-5"><div class="spinner-border" role="status"><span class="sr-only">Loading...</span></div></div>');
#             $request = $.ajax({
#                 url: buildUrl(),
#                 success: function(response) {
#                     const $html = $($.parseHTML(response))
#                     $('#jobs .main').html($html.find('#jobs .main').html())
#                     $('nav.pagination-nav').html($html.find('nav.pagination-nav').html())
#                     $('#jobs').get(0).scrollIntoView();
#                 }
#             });
#             if (closeSearch) {
#                 $('.search-block').removeClass('open');
#             }
#         };
#
#         var changeDateId = function(id, redirect = true) {
#             $('a[data-date]').removeClass('selected')
#             dateId = dateId === id ? '' : id
#             if (dateId) {
#                 $('a[data-date="' + dateId + '"]').addClass('selected')
#             }
#             setFilters(redirect);
#         };
#
#         var changeJobTypeId = function(id, redirect = true) {
#             $('a[data-job-type]').removeClass('selected')
#             jobTypeId = parseInt(jobTypeId) === parseInt(id) ? '' : id;
#             if (jobTypeId) {
#                 $('a[data-job-type=' + jobTypeId + ']').addClass('selected')
#             }
#             setFilters(redirect);
#         };
#
#         var changePositionId = function(id, redirect = true) {
#             $('a[data-position]').removeClass('selected')
#             if (parseInt(positionId) === parseInt(id)) {
#                 positionId = "";
#             } else {
#                 $('a[data-position=' + id + ']').addClass('selected')
#                 positionId = id;
#             }
#             setFilters(redirect);
#         };
#
#         var changeFocusId = function(id, redirect = true) {
#             focusId = id;
#             setFilters(redirect);
#         };
#
#         var changeLocationId = function(id, redirect = true) {
#             $('a[data-location]').removeClass('selected')
#             locationId = parseInt(locationId) === parseInt(id) ? '' : id;
#             if (locationId) {
#                 $('a[data-location=' + locationId + ']').addClass('selected')
#             }
#             setFilters(redirect);
#         };
#
#         var changeSalaryId = function(id, redirect = true) {
#             salaryId = id;
#             setFilters(redirect);
#         };
#
#         var changeIndustryId = function(id, redirect = true) {
#             $('input[type="checkbox"][name="industries\[\]"]').removeAttr('checked')
#             $('#industry-' + id).attr('checked', 'checked')
#             industryIds = [id];
#             diversity = 0;
#             setFilters(redirect);
#         };
#
#         var addIndustryId = function(id, redirect = true) {
#             industryIds.push(id);
#             setFilters(redirect, false);
#         };
#
#         var changeVirtual = function(id, redirect = true) {
#             $('a[data-virtual]').removeClass('selected')
#             virtual = parseInt(virtual) === parseInt(id) ? '' : id;
#             if (virtual !== '') {
#                 $('a[data-virtual="' + virtual + '"]').addClass('selected')
#             }
#             setFilters(redirect);
#         }
#
#         var changePage = function(id, redirect = true) {
#             page = id;
#             setFilters(redirect, true, page);
#         };
#
#         var toggleIndustry = function($checkbox)
#         {
#             if ($checkbox.prop('checked') === true) {
#                 addIndustryId(parseInt($checkbox.data('id')));
#             } else {
#                 removeIndustryId(parseInt($checkbox.data('id')));
#             }
#         };
#
#         var removeIndustryId = function(id) {
#             var ids = [];
#             for (var i = 0; i < industryIds.length; i++) {
#                 if (industryIds[i] !== id) {
#                     ids.push(industryIds[i]);
#                 }
#             }
#
#             industryIds = ids;
#             setFilters(true, false);
#         };
#
#         var changeKeywords = function()
#         {
#             keywords = $('#keywords').val();
#             setFilters();
#             $('.search-block').removeClass('open');
#         };
#
#         var setKeywords = function(text)
#         {
#             keywords = text;
#             setFilters();
#         };
#
#         var toggleDiversity = function()
#         {
#             diversity = diversity == 1 ? 0 : 1;
#             if (diversity) {
#                 $('input[name="diversity"]').attr('checked', 'checked')
#             } else {
#                 $('input[name="diversity"]').removeAttr('checked')
#             }
#             industryIds = [];
#             setFilters();
#         };
#
#         $(document)
#             .on('keypress', '#keywords', function (e) {
#                 console.log('keypress', e.keyCode)
#                 if (e.keyCode === 13) {
#                     changeKeywords()
#                     $(this).blur()
#                 }
#             })
#             .on('click', '.section h4', function() {
#                 $(this).parent().toggleClass('open');
#             })
#             .on('click', '#filter-results', function() {
#                 $('.search-block').toggleClass('open');
#             })
#             .on('keypress', '#keywords', function(event) {
#                 const keycode = (event.keyCode ? event.keyCode : event.which);
#                 if (keycode === '13') {
#                     changeKeywords();
#                 }
#             })
#             .on('change', '#count', function() {
#                 perPage = parseInt($(this).val());
#                 setFilters();
#             })
#             .on('click', '.location-show-more', function(e) {
#                 e.preventDefault();
#                 $('.location-options li').show();
#                 $('.location-show-more').hide();
#             })
#             .on('click', '.tabs .browse', function() {
#                 $('.panel.browse').show();
#                 $('.panel.detailed').hide();
#                 $(this).addClass('open');
#                 $('.tabs .detailed').removeClass('open');
#             })
#             .on('click', '.tabs .detailed', function() {
#                 $('.panel.browse').hide();
#                 $('.panel.detailed').show();
#                 $(this).addClass('open');
#                 $('.tabs .browse').removeClass('open');
#             })
#             .on('click', '.see-more-industries', function(e) {
#                 e.preventDefault();
#                 $('.industries .checkbox-list-hidden').css('display', 'grid');
#                 $(this).hide();
#                 $('.hide-more-industries').show();
#             })
#             .on('click', '.hide-more-industries', function(e) {
#                 e.preventDefault();
#                 $('.industries .checkbox-list-hidden').hide();
#                 $(this).hide();
#                 $('.see-more-industries').show();
#             })
#         ;
#     </script>
# <script src="/js/base.js?t=1692816731"></script>
# </body>
# </html>

# %%
pagination = soup.find('ul', {'class': 'pagination'})

# %%
pagination
# Out:
# <ul class="pagination">
# <li class="page-item active"><a class="page-link" onclick="changePage(1)">1</a></li>
# <li class="page-item"><a class="page-link" onclick="changePage(2)">2</a></li>
# <li class="page-item"><a class="page-link" onclick="changePage(3)">3</a></li>
# <li class="page-item"><a class="page-link bg-green" onclick="changePage(2)">Next <i class="fas fa-chevron-right" style="font-size: 0.85rem;"></i></a></li>
# </ul>

# %%
# grab a list of `li` ("list element") elements
pages = pagination.find_all('li')

# %%
pages
# Out:
# [<li class="page-item active"><a class="page-link" onclick="changePage(1)">1</a></li>,
#  <li class="page-item"><a class="page-link" onclick="changePage(2)">2</a></li>,
#  <li class="page-item"><a class="page-link" onclick="changePage(3)">3</a></li>,
#  <li class="page-item"><a class="page-link bg-green" onclick="changePage(2)">Next <i class="fas fa-chevron-right" style="font-size: 0.85rem;"></i></a></li>]

# %%
# for this website, the button for the last page is always the second-to-last `li` element
# (the last one is the "Next" button)
# use negative list indexing to grab the second-to-last item
# https://stackoverflow.com/a/11367936
last_page_button = pages[-2]

# %%
last_page_button
# Out:
# <li class="page-item"><a class="page-link" onclick="changePage(3)">3</a></li>

# %%
# grab just the text, and we're going to use it as a number, so grab the text and
# coerce the string to an integer
last_page = int(last_page_button.text)

# %%
last_page
# Out:
# 3

# %%
# now we know how many pages to iterate through! set up a range and start graabbing pages
# note that the range excludes the last number, so we need to add 1 to the top end of the range
# https://docs.python.org/3/library/functions.html#func-range

# the goal is to fetch each page and write the content to file
for page_num in range(1, last_page+1):

    # use the page number to build the request
    req = requests.get(
        base_url,
        params={
            'page': page_num,
            'count': 100
        }
    )

    # write the HTML to file -- use an f-string to format the filename
    # https://docs.python.org/3/tutorial/inputoutput.html#tut-f-strings
    filename = f'journo-jobs-page-{page_num}.html'
    with open(filename, 'w') as outfile:
        outfile.write(req.text)

    # a little status message
    print(f'Wrote {filename}')

    # pause for half a second
    sleep(0.5)
# Out:
# Wrote journo-jobs-page-1.html
# Wrote journo-jobs-page-2.html
# Wrote journo-jobs-page-3.html

# %%
# use the glob module to get a handle to the HTML files we just wrote
# https://docs.python.org/3/library/glob.html
# the asterisk is a wildcard meaning "zero or more characters of any kind"
html_files = glob('*.html')

# %%
html_files
# Out:
# ['journo-jobs-page-2.html',
#  'journo-jobs-page-3.html',
#  'journo-jobs-page-1.html']

# %%
# loop over those filenames, open each file and parse out the contents

# first, set up a tracking list for the parsed data
data = []

# loop over the file names
for file in html_files:

    # open the file in read mode and get a handle to the file contents
    with open(file, 'r') as infile:
        html = infile.read()

    # turn the HTML into soup
    soup = BeautifulSoup(html, 'html.parser')

    # get the main div
    div = soup.find('div', {'class': 'main'})

    # each row div is wrapped in an `a` tag, so grab those
    links = div.find_all('a', {'class': 'job-item'})

    # loop over each of those links
    for link in links:

        # grab the relative URL
        url = link['href']

        # turn it into a fully qualified URL using an f-string
        url = f'https://journalismjobs.com{url}'

        # grab the job title
        job_title = link.find('h3').text.strip()

        # newsroom
        newsroom = link.find('div', {'class': 'job-item-company'}).text.strip()

        # location, job type and date posted are all findable by looking up the icon,
        # then finding the text of the parent -- only if it exists (need to test)
        location = link.find('i', {'class': 'fa-map-marker-alt'})
        if location:
            location = location.parent.text.strip()

        job_type = link.find('i', {'class': 'fa-clock'})
        if job_type:
            job_type = job_type.parent.text.strip()

        date_posted = link.find('i', {'class': 'fa-calendar'})
        if date_posted:
            # remove "Posted " while we're at it
            date_posted = date_posted.parent.text.strip().replace('Posted ', '')

        # 💪 extra credit: figure out how to use the `datetime` module to add the
        # current year to the `date_posted` string
        
        # grab the list of industries
        industries = link.find('ul', {'class': 'job-item-industries'})
        
        # start an empty list to keep track of industries (or will remain empty if no list exists)
        industry_list = []
        if industries:
            for li in industries.find_all('li'):
                industry_list.append(li.text.strip())

        # join the list of industries with a comma and a space
        # https://docs.python.org/3/library/stdtypes.html#str.join
        industry_list = ', '.join(industry_list)
        
        row_data = [
            url,
            job_title,
            newsroom,
            location,
            job_type,
            date_posted,
            industry_list            
        ]

        data.append(row_data)

# %%
# write to file

# CSV headers, in order
csv_headers = [
    'url',
    'job_title',
    'newsroom',
    'location',
    'job_type',
    'date_posted',
    'industry_list'
]

with open('journo-jobs.csv', 'w') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(csv_headers)
    writer.writerows(data)
